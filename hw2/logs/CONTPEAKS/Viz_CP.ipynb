# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
## collecting best paths:
best_paths = []

# %%
## Looking for the best MIMIC output
paths = glob.glob('*MIMIC*.csv')
print(paths)
# Out:
# ['CONTPEAKS_MIMIC100_50_0.1_1_LOG.csv', 'CONTPEAKS_MIMIC100_50_0.3_1_LOG.csv', 'CONTPEAKS_MIMIC100_50_0.5_1_LOG.csv', 'CONTPEAKS_MIMIC100_50_0.7_1_LOG.csv', 'CONTPEAKS_MIMIC100_50_0.9_1_LOG.csv']

# %%
plt.figure()
for i,path in enumerate(paths):
    df = pd.read_csv(path)
    plt.plot(df['fitness'],label=i)

plt.title('Change in fitness function value in MIMIC')
plt.legend()
plt.show()

# %%
best_paths.append(paths[0])

# %%
## Looking for the best Simulated Annealing output
paths = glob.glob('*SA*.csv')
print(paths)
# Out:
# ['CONTPEAKS_SA0.15_1_LOG.csv', 'CONTPEAKS_SA0.15_2_LOG.csv', 'CONTPEAKS_SA0.35_1_LOG.csv', 'CONTPEAKS_SA0.35_2_LOG.csv', 'CONTPEAKS_SA0.55_1_LOG.csv', 'CONTPEAKS_SA0.55_2_LOG.csv', 'CONTPEAKS_SA0.75_1_LOG.csv', 'CONTPEAKS_SA0.75_2_LOG.csv', 'CONTPEAKS_SA0.95_1_LOG.csv', 'CONTPEAKS_SA0.95_2_LOG.csv']

# %%
plt.figure()
for i,path in enumerate(paths):
    df = pd.read_csv(path)
    plt.plot(df['fitness'],label=i)

plt.title('Change in fitness function value in Simulated Annealing')
plt.legend()
plt.show()

# %%
best_paths.append(paths[8])

# %%
## Looking for the best Simulated Annealing output
paths = glob.glob('*GA*.csv')
print(paths)
# Out:
# ['CONTPEAKS_GA100_10_10_1_LOG.csv', 'CONTPEAKS_GA100_10_10_2_LOG.csv', 'CONTPEAKS_GA100_10_30_1_LOG.csv', 'CONTPEAKS_GA100_10_30_2_LOG.csv', 'CONTPEAKS_GA100_30_10_1_LOG.csv', 'CONTPEAKS_GA100_30_10_2_LOG.csv', 'CONTPEAKS_GA100_30_30_1_LOG.csv', 'CONTPEAKS_GA100_30_30_2_LOG.csv', 'CONTPEAKS_GA100_50_10_1_LOG.csv', 'CONTPEAKS_GA100_50_10_2_LOG.csv', 'CONTPEAKS_GA100_50_30_1_LOG.csv', 'CONTPEAKS_GA100_50_30_2_LOG.csv']

# %%
plt.figure()
for i,path in enumerate(paths):
    df = pd.read_csv(path)
    plt.plot(df['fitness'],label=i)

plt.title('Change in fitness function value in Genetic Algorithm')
plt.legend()
plt.show()

# %%
best_paths.append(paths[7])

# %%
## Looking for the best Randomized Hill Climbing output
paths = glob.glob('*RHC*.csv')
print(paths)
# Out:
# ['CONTPEAKS_RHC_1_LOG.csv', 'CONTPEAKS_RHC_2_LOG.csv']

# %%
plt.figure()
for i,path in enumerate(paths):
    df = pd.read_csv(path)
    plt.plot(df['fitness'],label=i)

plt.title('Obj value using Randomized Hill Climbing')
plt.legend()
plt.show()

# %%
best_paths.append(paths[0])

# %%
best_paths
# Out:
# ['CONTPEAKS_MIMIC100_50_0.1_1_LOG.csv',
#  'CONTPEAKS_SA0.95_1_LOG.csv',
#  'CONTPEAKS_GA100_30_30_2_LOG.csv',
#  'CONTPEAKS_RHC_1_LOG.csv']

# %%
plt.figure()
for i,path in enumerate(best_paths):
    df = pd.read_csv(path)
    plt.plot(df['fitness'],label=path.split('_')[1])
             
    best_obj = df.iloc[-1].fitness
    final_time = df.iloc[-1].time
    print(path.split('_')[1],best_obj,final_time)
    

plt.title('Max Obj Value using 4 algorithms')
plt.legend()
plt.show()
# Out:
# ('MIMIC100', 76.0, 379.40037675300005)
# ('SA0.95', 200.0, 0.059945177000099999)
# ('GA100', 158.0, 1.7272026009999999)
# ('RHC', 119.0, 0.161298829)

# %%
df.iloc[-1].fitness
# Out:
# 119.0
